# %% [markdown]
# # Tarea Semana 1

# %% [markdown]
# ## Tarea Programada

# %% [markdown]
# Utilice el dataset de precios de casas en [Boston](https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_boston.html#sklearn.datasets.load_boston) para predecir el precio de las casas utilizando 1 sola característica (feature)
# 1. Separe el dataset en Train y Test (1 pt)
# 2. Dibuje un gráfico para cada dataset (4 pts)
# 3. Cual es la distribución de los precios, utilice un histograma para presentarla (1 pt)
# 4. Ajuste un modelo con scikitlearn para predecir los precios (2 pts)
# 5. Grafique cada dataset con su respectiva linea de predicción (4 pts)
# 6. Utilice RMSE como métrica del error (2 pts)

# %%
from sklearn.datasets import load_boston
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets

# %%
X, y = load_boston(return_X_y=True)
#X.shape

# %%
X
# Out:
# array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#         4.9800e+00],
#        [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#         9.1400e+00],
#        [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#         4.0300e+00],
#        ...,
#        [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         5.6400e+00],
#        [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#         6.4800e+00],
#        [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         7.8800e+00]])

# %%
datasets.load_boston().feature_names
# Out:
# array(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD',
#        'TAX', 'PTRATIO', 'B', 'LSTAT'], dtype='<U7')

# %%
print(load_boston().DESCR)
# Out:
# .. _boston_dataset:
#
# Boston house prices dataset
# ---------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
# ...

# %% [markdown]
# 7. Utilice otro regresor de [scikitlearn](https://scikit-learn.org/stable/supervised_learning.html#supervised-learning) o alguna otra biblioteca de AI para mejorar la predicción utilizando el mismo X. Sugerencias: Ordinary Least Squares, Lasso o Ridge (2 pts)

# %%
#Define features
MEDV = X[:, np.newaxis, 12]

# %%
MEDV
# Out:
# array([[ 4.98],
#        [ 9.14],
#        [ 4.03],
#        [ 2.94],
#        [ 5.33],
#        [ 5.21],
#        [12.43],
#        [19.15],
#        [29.93],
#        [17.1 ],
#        [20.45],
#        [13.27],
#        [15.71],
#        [ 8.26],
#        [10.26],
#        [ 8.47],
#        [ 6.58],
#        [14.67],
#        [11.69],
#        [11.28],
#        [21.02],
#        [13.83],
#        [18.72],
#        [19.88],
#        [16.3 ],
#        [16.51],
#        [14.81],
#        [17.28],
#        [12.8 ],
#        [11.98],
#        [22.6 ],
#        [13.04],
#        [27.71],
#        [18.35],
#        [20.34],
#        [ 9.68],
#        [11.41],
#        [ 8.77],
#        [10.13],
#        [ 4.32],
#        [ 1.98],
#        [ 4.84],
#        [ 5.81],
#        [ 7.44],
#        [ 9.55],
#        [10.21],
#        [14.15],
#        [18.8 ],
#        [30.81],
#        [16.2 ],
#        [13.45],
#        [ 9.43],
#        [ 5.28],
#        [ 8.43],
#        [14.8 ],
# ...

# %%
predicted = y

# %%
#Separe el dataset en Train y Test (1 pt)
#Dataset split
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(MEDV, predicted, test_size=0.30, random_state=50)

# %% [markdown]
# ## Video de la Semana
#
# [All Machine Learning Models Explained in 5 Minutes](https://www.youtube.com/watch?v=yN7ypxC7838&t=26s)

# %%
#Dibuje un grafico para cada dataset
plt.scatter(MEDV, predicted, marker = ".", s = 60, c = "green")
plt.xlabel("Median Value - MEDV($1000 scale)")
plt.ylabel("Price prediction")
plt.show()

# %%
#2.Dibuje un gráfico para cada dataset (4 pts)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 8))
ax1.scatter(X_train,y_train, marker = ".", s = 60, c = "blue")
ax2.scatter(X_test,y_test, marker = ".", s = 60, c = "red")
fig.text(0.5, 0.04, 'Median value-MEDV', ha='center')
fig.text(0.09, 0.5, 'Price Prediction', va='center', rotation='vertical')
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 8))
#fig,ax = plt.subplots(1,1)
a = MEDV
n_bins=20
ax1.hist(a, bins = n_bins)
ax1.set_title("Prices")
ax1.set_xticks([0,10,20,30,40,50])
ax1.set_xlabel('Prices')
ax1.set_ylabel('no. of houses')

b=predicted
n_bins=20
ax2.hist(a, bins = n_bins)
ax2.set_title("Prices")
ax2.set_xticks([0,10,20,30,40,50])
ax2.set_xlabel('Prices')
ax2.set_ylabel('no. of houses')
plt.show()

# %% [markdown]
# ## Lectura Recomendada
#
# Capítulos 1 del libro: An Introduction to Statistical Learning
#
# > James, G., Witten, D., Hastie, T., & Tibshirani, R. (2013). An introduction to statistical learning (Vol. 112, p. 18). New York: springer.
